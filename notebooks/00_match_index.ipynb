# %% [markdown]
# # 00 - Indice de Partidas
#
# Cria e atualiza o indice central de partidas.

# %%
match_id = None
match_date = None
run_scope = "torneio"
source = "worldcup2026"
force_refresh = False
write_outputs = True

# %%
from fifa_analytics.config import load_config

pipeline_config = load_config("pipeline.yaml")
pipeline_config["competition"]
