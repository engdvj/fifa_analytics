# %% [markdown]
# # 01 - Ingestao de Fontes
#
# Coleta dados das fontes e salva snapshots raw.

# %%
match_id = None
match_date = None
run_scope = "data_de_jogos"
source = "worldcup2026"
force_refresh = False
write_outputs = True

# %%
from fifa_analytics.config import load_config

sources = load_config("sources.yaml")
sources["sources"].get(source)
