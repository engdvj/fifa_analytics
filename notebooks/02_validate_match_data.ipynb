# %% [markdown]
# # 02 - Validacao de Dados da Partida
#
# Valida dados de partidas, schemas e divergencias entre fontes.

# %%
match_id = None
match_date = None
run_scope = "jogo_unico"
source = "worldcup2026"
force_refresh = False
write_outputs = True

# %%
from fifa_analytics.validation.match_validation import compare_match_records

compare_match_records({}, {})
