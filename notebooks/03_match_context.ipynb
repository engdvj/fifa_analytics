# %% [markdown]
# # 03 - Contexto da Partida
#
# Gera contexto pre ou pos-jogo.

# %%
match_id = None
match_date = None
run_scope = "jogo_unico"
source = "worldcup2026"
force_refresh = False
write_outputs = True
