# %% [markdown]
# # 05 - Eventos da Partida
#
# Monta timeline de gols, cartoes, substituicoes e eventos relevantes.

# %%
match_id = None
match_date = None
run_scope = "jogo_unico"
source = "worldcup2026"
force_refresh = False
write_outputs = True
