# %% [markdown]
# # 09 - Montagem do Relatorio
#
# Monta o relatorio final por jogo a partir dos fragmentos.

# %%
match_id = None
match_date = None
run_scope = "jogo_unico"
source = "worldcup2026"
force_refresh = False
write_outputs = True

# %%
from fifa_analytics.reporting.build_report import build_match_report

if match_id and write_outputs:
    result = build_match_report(match_id)
    result
else:
    "Informe match_id para montar um relatorio."
