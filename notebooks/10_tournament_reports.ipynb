# %% [markdown]
# # 10 - Relatorios do Torneio
#
# Gera relatorios agregados do torneio.

# %%
match_id = None
match_date = None
run_scope = "torneio"
source = "worldcup2026"
force_refresh = False
write_outputs = True
